# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh45-nandan/CNN_BASELINE_MODLES_FOR_CRC/blob/main/efficientB4_modifies_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ZIP_IN_DRIVE = "/content/drive/MyDrive/archive (2).zip"

# ---- Installs ----
# !pip install -q tensorflow keras opencv-python matplotlib seaborn scikit-learn

# ---- Mount Drive ----
from google.colab import drive
drive.mount('/content/drive')

# ---- Imports ----
import os, glob, shutil, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras import regularizers, callbacks, optimizers

print("✅ Libraries ready")

# ==========================================================
# 📦 ZIP Extraction
# ==========================================================
if not ZIP_IN_DRIVE or not os.path.exists(ZIP_IN_DRIVE):
    raise FileNotFoundError("❌ ZIP_IN_DRIVE path is not set correctly.")

EXTRACT_DIR = "/content/Extracted_Kather"
if os.path.exists(EXTRACT_DIR):
    shutil.rmtree(EXTRACT_DIR)
os.makedirs(EXTRACT_DIR, exist_ok=True)

print(f"📦 Unzipping dataset from:\n→ {ZIP_IN_DRIVE}")
# !unzip -q -o "$ZIP_IN_DRIVE" -d "$EXTRACT_DIR"

# Auto-detect dataset root
def find_dataset_root(base):
    best, best_count = base, 0
    for root, dirs, _ in os.walk(base):
        if len(dirs) > best_count:
            best, best_count = root, len(dirs)
    return best

SOURCE_DIR = find_dataset_root(EXTRACT_DIR)
print(f"✅ Dataset root detected at: {SOURCE_DIR}")

# ==========================================================
# ⚙️ Reproducibility & Split Ratios
# ==========================================================
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

VAL_RATIO = 0.20
TEST_RATIO = 0.15
IMG_SIZE = (380, 380)
BATCH_SIZE = 32

EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")

# ==========================================================
# 🔎 Discover Classes & Files
# ==========================================================
def list_images_recursive(folder):
    out = []
    for root, _, files in os.walk(folder):
        for fn in files:
            if os.path.splitext(fn)[1] in EXTS:
                out.append(os.path.join(root, fn))
    return sorted(out)

class_to_files = {}
for cls in sorted(os.listdir(SOURCE_DIR)):
    p = os.path.join(SOURCE_DIR, cls)
    if os.path.isdir(p):
        files = list_images_recursive(p)
        if files:
            class_to_files[cls] = files

available_classes = sorted(class_to_files.keys())
if len(available_classes) == 0:
    raise RuntimeError("❌ No classes detected! Check ZIP structure.")

print("\n📚 Classes detected:")
for c in available_classes:
    print(f"  - {c}: {len(class_to_files[c])} images")

# ==========================================================
# 🧩 Stratified Split (Same as RL)
# ==========================================================
SPLIT_ROOT = "/content/kather_split_baseline"
TRAIN_DIR = SPLIT_ROOT + "/train"
VAL_DIR   = SPLIT_ROOT + "/val"
TEST_DIR  = SPLIT_ROOT + "/test"

if os.path.exists(SPLIT_ROOT):
    shutil.rmtree(SPLIT_ROOT)
os.makedirs(TRAIN_DIR); os.makedirs(VAL_DIR); os.makedirs(TEST_DIR)

def allocate_counts(n, val_ratio=VAL_RATIO, test_ratio=TEST_RATIO):
    if n <= 0: return (0,0,0)
    if n == 1: return (1,0,0)
    if n == 2: return (1,0,1)
    test_n = max(1, int(n * test_ratio))
    val_n  = max(1, int(n * val_ratio))
    if test_n + val_n >= n:
        val_n = 1; test_n = 1
    train_n = n - val_n - test_n
    return (train_n, val_n, test_n)

rng = np.random.default_rng(SEED)
totals = {"train":0,"val":0,"test":0}

for cls in available_classes:
    files = class_to_files[cls]
    idx = np.arange(len(files))
    rng.shuffle(idx)

    train_n, val_n, test_n = allocate_counts(len(files))
    train_idx = set(idx[:train_n])
    val_idx   = set(idx[train_n:train_n+val_n])
    test_idx  = set(idx[train_n+val_n:train_n+val_n+test_n])

    os.makedirs(f"{TRAIN_DIR}/{cls}")
    os.makedirs(f"{VAL_DIR}/{cls}")
    os.makedirs(f"{TEST_DIR}/{cls}")

    for i in idx:
        src = files[i]
        base = os.path.basename(src)
        if i in train_idx: dst = f"{TRAIN_DIR}/{cls}/{base}"
        elif i in val_idx: dst = f"{VAL_DIR}/{cls}/{base}"
        else:              dst = f"{TEST_DIR}/{cls}/{base}"
        shutil.copy2(src, dst)

    totals["train"] += train_n
    totals["val"]   += val_n
    totals["test"]  += test_n

print("\n✅ Stratified Split Completed:")
print(totals)

# ==========================================================
# 📊 Visualization of Dataset Split
# ==========================================================
split_counts = []
for split in ['train', 'val', 'test']:
    for cls in available_classes:
        folder = os.path.join(SPLIT_ROOT, split, cls)
        count = len(glob.glob(folder + '/*'))
        split_counts.append({'Split': split, 'Class': cls, 'Count': count})

df_counts = pd.DataFrame(split_counts)

# --- Bar Chart ---
plt.figure(figsize=(12, 6))
sns.barplot(data=df_counts, x='Class', y='Count', hue='Split')
plt.title('📊 Dataset Split per Class (Train / Val / Test)')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.legend(title='Split')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# --- Pie Chart (Overall Split Ratios) ---
plt.figure(figsize=(5,5))
split_totals = df_counts.groupby('Split')['Count'].sum()
plt.pie(split_totals, labels=split_totals.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99','#ff9999'])
plt.title('Dataset Split Ratios (Overall)')
plt.show()

print("\n📦 Total Image Distribution:\n", split_totals)

# ==========================================================
# 🔄 Data Generators (Same as RL)
# ==========================================================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.2, height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True, vertical_flip=True,
    brightness_range=[0.8,1.2],
    shear_range=0.2,
    fill_mode="reflect"
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True)
val_gen   = val_test_datagen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_gen  = val_test_datagen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)

class_names = list(train_gen.class_indices.keys())
num_classes = len(class_names)
print(f"\n✅ Detected {num_classes} classes: {class_names}")

# ==========================================================
# 🧠 Build EfficientNetB4 Baseline Model
# ==========================================================
base_model = EfficientNetB4(weights='imagenet', include_top=False, input_shape=IMG_SIZE + (3,))
base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
    Dropout(0.4),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# ==========================================================
# 🏋️ Training Phase 1
# ==========================================================
checkpoint_cb = callbacks.ModelCheckpoint('/content/baseline_best_phase1.h5', save_best_only=True, monitor='val_loss', mode='min')
earlystop_cb = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)

EPOCHS_INITIAL = 15
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_INITIAL, callbacks=[checkpoint_cb, earlystop_cb, reduce_lr])

# ==========================================================
# 🔓 Fine-tuning Phase
# ==========================================================
base_model.trainable = True
for layer in base_model.layers[:-50]:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

EPOCHS_FINE = 25
history_fine = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_FINE, callbacks=[checkpoint_cb, earlystop_cb, reduce_lr])

# ==========================================================
# 🧾 Evaluation
# ==========================================================
model.load_weights('/content/baseline_best_phase1.h5')
test_loss, test_acc = model.evaluate(test_gen, verbose=1)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

# Confusion Matrix
y_true = test_gen.classes
y_pred = np.argmax(model.predict(test_gen, verbose=0), axis=1)
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix — EfficientNetB4 Baseline")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# ==========================================================
# 🧭 Training vs Validation Curves
# ==========================================================
acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history.history['loss'] + history_fine.history['loss']
val_loss = history.history['val_loss'] + history_fine.history['val_loss']

plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.plot(acc, label='Train Accuracy')
plt.plot(val_acc, label='Val Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")

plt.subplot(1,2,2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.show()

# ==========================================================
# 💾 Save Final Model
# ==========================================================
model.save('/content/efficientnetb4_colorectal_baseline_final.h5')
print("✅ Final Model Saved at /content/efficientnetb4_colorectal_baseline_final.h5")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Libraries ready
# 📦 Unzipping dataset from:
# → /content/drive/MyDrive/archive (2).zip
# ✅ Dataset root detected at: /content/Extracted_Kather/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000
#
# 📚 Classes detected:
#   - 01_TUMOR: 625 images
#   - 02_STROMA: 625 images
#   - 03_COMPLEX: 625 images
#   - 04_LYMPHO: 625 images
#   - 05_DEBRIS: 625 images
#   - 06_MUCOSA: 625 images
#   - 07_ADIPOSE: 625 images
#   - 08_EMPTY: 625 images
#
# ✅ Stratified Split Completed:
# {'train': 3256, 'val': 1000, 'test': 744}
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📦 Total Image Distribution:
#  Split
# test      744
# train    3256
# val      1000
# Name: Count, dtype: int64
# Found 3256 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# Found 744 images belonging to 8 classes.
#
# ✅ Detected 8 classes: ['01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO', '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY']
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb4 (Functional)     │ (None, 12, 12, 1792)   │    17,673,823 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1792)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       459,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,134,887 (69.18 MB)
#  Trainable params: 461,064 (1.76 MB)
#  Non-trainable params: 17,673,823 (67.42 MB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2994 - loss: 1.9224
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 0.3004 - loss: 1.9201 - val_accuracy: 0.6970 - val_loss: 1.1965 - learning_rate: 1.0000e-04
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5774 - loss: 1.2700
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.5776 - loss: 1.2693 - val_accuracy: 0.7250 - val_loss: 0.9302 - learning_rate: 1.0000e-04
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6550 - loss: 1.0202
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.6552 - loss: 1.0199 - val_accuracy: 0.7880 - val_loss: 0.7651 - learning_rate: 1.0000e-04
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7163 - loss: 0.8733
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7163 - loss: 0.8733 - val_accuracy: 0.8040 - val_loss: 0.6787 - learning_rate: 1.0000e-04
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7172 - loss: 0.8374
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7172 - loss: 0.8373 - val_accuracy: 0.8090 - val_loss: 0.6235 - learning_rate: 1.0000e-04
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7425 - loss: 0.7866
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7425 - loss: 0.7865 - val_accuracy: 0.8230 - val_loss: 0.5906 - learning_rate: 1.0000e-04
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7779 - loss: 0.7066
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7778 - loss: 0.7068 - val_accuracy: 0.8380 - val_loss: 0.5533 - learning_rate: 1.0000e-04
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7441 - loss: 0.7515
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7441 - loss: 0.7515 - val_accuracy: 0.8400 - val_loss: 0.5327 - learning_rate: 1.0000e-04
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7751 - loss: 0.7055
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7751 - loss: 0.7054 - val_accuracy: 0.8500 - val_loss: 0.5152 - learning_rate: 1.0000e-04
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7733 - loss: 0.6773
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7733 - loss: 0.6772 - val_accuracy: 0.8490 - val_loss: 0.4890 - learning_rate: 1.0000e-04
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7751 - loss: 0.6624
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7751 - loss: 0.6625 - val_accuracy: 0.8520 - val_loss: 0.4884 - learning_rate: 1.0000e-04
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7740 - loss: 0.6528
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7740 - loss: 0.6528 - val_accuracy: 0.8540 - val_loss: 0.4711 - learning_rate: 1.0000e-04
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7981 - loss: 0.6118
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7980 - loss: 0.6119 - val_accuracy: 0.8590 - val_loss: 0.4636 - learning_rate: 1.0000e-04
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7727 - loss: 0.6683
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7727 - loss: 0.6682 - val_accuracy: 0.8690 - val_loss: 0.4526 - learning_rate: 1.0000e-04
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8055 - loss: 0.6020 - val_accuracy: 0.8550 - val_loss: 0.4602 - learning_rate: 1.0000e-04
# Epoch 1/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.7004 - loss: 1.0198 - val_accuracy: 0.8160 - val_loss: 0.5932 - learning_rate: 1.0000e-05
# Epoch 2/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.7318 - loss: 0.8764 - val_accuracy: 0.8130 - val_loss: 0.6267 - learning_rate: 1.0000e-05
# Epoch 3/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.7423 - loss: 0.8434 - val_accuracy: 0.8250 - val_loss: 0.6002 - learning_rate: 1.0000e-05
# Epoch 4/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.7609 - loss: 0.7699 - val_accuracy: 0.8320 - val_loss: 0.5637 - learning_rate: 1.0000e-05
# Epoch 5/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7771 - loss: 0.7244 - val_accuracy: 0.8430 - val_loss: 0.5256 - learning_rate: 1.0000e-05
# Epoch 6/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.7816 - loss: 0.6783 - val_accuracy: 0.8500 - val_loss: 0.4920 - learning_rate: 1.0000e-05
# Epoch 7/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8053 - loss: 0.6149 - val_accuracy: 0.8640 - val_loss: 0.4655 - learning_rate: 1.0000e-05
# Epoch 8/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7948 - loss: 0.6166
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7950 - loss: 0.6164 - val_accuracy: 0.8700 - val_loss: 0.4458 - learning_rate: 1.0000e-05
# Epoch 9/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8245 - loss: 0.5753
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8245 - loss: 0.5752 - val_accuracy: 0.8770 - val_loss: 0.4271 - learning_rate: 1.0000e-05
# Epoch 10/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8170 - loss: 0.5674
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.8170 - loss: 0.5673 - val_accuracy: 0.8810 - val_loss: 0.4139 - learning_rate: 1.0000e-05
# Epoch 11/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8203 - loss: 0.5536
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.8203 - loss: 0.5536 - val_accuracy: 0.8850 - val_loss: 0.4000 - learning_rate: 1.0000e-05
# Epoch 12/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8242 - loss: 0.5640
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8243 - loss: 0.5639 - val_accuracy: 0.8890 - val_loss: 0.3891 - learning_rate: 1.0000e-05
# Epoch 13/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8244 - loss: 0.5530
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8244 - loss: 0.5530 - val_accuracy: 0.8900 - val_loss: 0.3807 - learning_rate: 1.0000e-05
# Epoch 14/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8471 - loss: 0.4839
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8471 - loss: 0.4841 - val_accuracy: 0.8920 - val_loss: 0.3753 - learning_rate: 1.0000e-05
# Epoch 15/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8394 - loss: 0.4949
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8394 - loss: 0.4950 - val_accuracy: 0.8900 - val_loss: 0.3662 - learning_rate: 1.0000e-05
# Epoch 16/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8455 - loss: 0.5116
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8454 - loss: 0.5117 - val_accuracy: 0.8980 - val_loss: 0.3576 - learning_rate: 1.0000e-05
# Epoch 17/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8466 - loss: 0.4739
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8466 - loss: 0.4739 - val_accuracy: 0.8950 - val_loss: 0.3521 - learning_rate: 1.0000e-05
# Epoch 18/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8590 - loss: 0.4599
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8589 - loss: 0.4600 - val_accuracy: 0.8960 - val_loss: 0.3475 - learning_rate: 1.0000e-05
# Epoch 19/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8499 - loss: 0.4668
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8499 - loss: 0.4669 - val_accuracy: 0.9000 - val_loss: 0.3397 - learning_rate: 1.0000e-05
# Epoch 20/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8549 - loss: 0.4400
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.8549 - loss: 0.4402 - val_accuracy: 0.9000 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 21/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8689 - loss: 0.4333
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.8688 - loss: 0.4334 - val_accuracy: 0.9050 - val_loss: 0.3277 - learning_rate: 1.0000e-05
# Epoch 22/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8602 - loss: 0.4448
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8602 - loss: 0.4448 - val_accuracy: 0.9040 - val_loss: 0.3237 - learning_rate: 1.0000e-05
# Epoch 23/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8647 - loss: 0.4597
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.8648 - loss: 0.4595 - val_accuracy: 0.9050 - val_loss: 0.3188 - learning_rate: 1.0000e-05
# Epoch 24/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8624 - loss: 0.4361
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8624 - loss: 0.4361 - val_accuracy: 0.9050 - val_loss: 0.3169 - learning_rate: 1.0000e-05
# Epoch 25/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8608 - loss: 0.4359
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8608 - loss: 0.4358 - val_accuracy: 0.9080 - val_loss: 0.3116 - learning_rate: 1.0000e-05
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.8900 - loss: 0.3836
#
# ✅ Test Accuracy: 91.40%
# ✅ Test Loss: 0.3049
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     01_TUMOR       0.95      0.92      0.93        93
#    02_STROMA       0.81      0.80      0.80        93
#   03_COMPLEX       0.78      0.84      0.81        93
#    04_LYMPHO       0.96      0.88      0.92        93
#    05_DEBRIS       0.86      0.89      0.87        93
#    06_MUCOSA       0.99      0.98      0.98        93
#   07_ADIPOSE       0.98      1.00      0.99        93
#     08_EMPTY       1.00      1.00      1.00        93
#
#     accuracy                           0.91       744
#    macro avg       0.92      0.91      0.91       744
# weighted avg       0.92      0.91      0.91       744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Final Model Saved at /content/efficientnetb4_colorectal_baseline_final.h5
