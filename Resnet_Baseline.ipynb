# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh45-nandan/CNN_BASELINE_MODLES_FOR_CRC/blob/main/Resnet_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  ResNet50 Fine-Tuning for Colorectal Histology


# ---- Installs ----
# !pip install -q tensorflow keras opencv-python matplotlib seaborn scikit-learn

# ---- Mount Drive ----
from google.colab import drive
drive.mount('/content/drive')

# ---- Imports ----
import os, glob, shutil, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras import regularizers, callbacks, optimizers

print("✅ Libraries ready")

# ==========================================================
# 📦 ZIP Extraction
# ==========================================================
ZIP_IN_DRIVE = "/content/drive/MyDrive/archive (2).zip"  # change if needed

if not ZIP_IN_DRIVE or not os.path.exists(ZIP_IN_DRIVE):
    raise FileNotFoundError("❌ ZIP_IN_DRIVE path is not set correctly.")

EXTRACT_DIR = "/content/Extracted_Kather"
if os.path.exists(EXTRACT_DIR):
    shutil.rmtree(EXTRACT_DIR)
os.makedirs(EXTRACT_DIR, exist_ok=True)

print(f"📦 Unzipping dataset from:\n→ {ZIP_IN_DRIVE}")
# !unzip -q -o "$ZIP_IN_DRIVE" -d "$EXTRACT_DIR"

# Auto-detect dataset root
def find_dataset_root(base):
    best, best_count = base, 0
    for root, dirs, _ in os.walk(base):
        if len(dirs) > best_count:
            best, best_count = root, len(dirs)
    return best

SOURCE_DIR = find_dataset_root(EXTRACT_DIR)
print(f"✅ Dataset root detected at: {SOURCE_DIR}")

# ==========================================================
# ⚙️ Reproducibility & Split Ratios
# ==========================================================
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

VAL_RATIO = 0.20
TEST_RATIO = 0.15
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")

# ==========================================================
# 🔎 Discover Classes & Files
# ==========================================================
def list_images_recursive(folder):
    out = []
    for root, _, files in os.walk(folder):
        for fn in files:
            if os.path.splitext(fn)[1].lower() in EXTS:
                out.append(os.path.join(root, fn))
    return sorted(out)

class_to_files = {}
for cls in sorted(os.listdir(SOURCE_DIR)):
    p = os.path.join(SOURCE_DIR, cls)
    if os.path.isdir(p):
        files = list_images_recursive(p)
        if files:
            class_to_files[cls] = files

available_classes = sorted(class_to_files.keys())
if len(available_classes) == 0:
    raise RuntimeError("❌ No classes detected! Check ZIP structure.")

print("\n📚 Classes detected:")
for c in available_classes:
    print(f"  - {c}: {len(class_to_files[c])} images")

# ==========================================================
# 🧩 Stratified Split
# ==========================================================
SPLIT_ROOT = "/content/kather_split_resnet"
TRAIN_DIR = SPLIT_ROOT + "/train"
VAL_DIR   = SPLIT_ROOT + "/val"
TEST_DIR  = SPLIT_ROOT + "/test"

if os.path.exists(SPLIT_ROOT):
    shutil.rmtree(SPLIT_ROOT)
os.makedirs(TRAIN_DIR); os.makedirs(VAL_DIR); os.makedirs(TEST_DIR)

def allocate_counts(n, val_ratio=VAL_RATIO, test_ratio=TEST_RATIO):
    if n <= 0: return (0,0,0)
    if n == 1: return (1,0,0)
    if n == 2: return (1,0,1)
    test_n = max(1, int(n * test_ratio))
    val_n  = max(1, int(n * val_ratio))
    if test_n + val_n >= n:
        val_n = 1; test_n = 1
    train_n = n - val_n - test_n
    return (train_n, val_n, test_n)

rng = np.random.default_rng(SEED)
totals = {"train":0,"val":0,"test":0}

for cls in available_classes:
    files = class_to_files[cls]
    idx = np.arange(len(files))
    rng.shuffle(idx)

    train_n, val_n, test_n = allocate_counts(len(files))
    train_idx = set(idx[:train_n])
    val_idx   = set(idx[train_n:train_n+val_n])
    test_idx  = set(idx[train_n+val_n:train_n+val_n+test_n])

    os.makedirs(f"{TRAIN_DIR}/{cls}")
    os.makedirs(f"{VAL_DIR}/{cls}")
    os.makedirs(f"{TEST_DIR}/{cls}")

    for i in idx:
        src = files[i]
        base = os.path.basename(src)
        if i in train_idx: dst = f"{TRAIN_DIR}/{cls}/{base}"
        elif i in val_idx: dst = f"{VAL_DIR}/{cls}/{base}"
        else:              dst = f"{TEST_DIR}/{cls}/{base}"
        shutil.copy2(src, dst)

    totals["train"] += train_n
    totals["val"]   += val_n
    totals["test"]  += test_n

print("\n✅ Stratified Split Completed:")
print(totals)

# ==========================================================
# 🔄 Data Generators
# ==========================================================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.2, height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True, vertical_flip=True,
    brightness_range=[0.8,1.2],
    shear_range=0.2,
    fill_mode="reflect"
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True)
val_gen   = val_test_datagen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_gen  = val_test_datagen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)

class_names = list(train_gen.class_indices.keys())
num_classes = len(class_names)
print(f"\n✅ Detected {num_classes} classes: {class_names}")

# ==========================================================
# 🧠 Build ResNet50 Baseline Model
# ==========================================================
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SIZE + (3,))
base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(512, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# ==========================================================
# 🏋️ Training Phase 1
# ==========================================================
checkpoint_cb = callbacks.ModelCheckpoint('/content/resnet50_best_phase1.h5', save_best_only=True, monitor='val_loss', mode='min')
earlystop_cb = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)

EPOCHS_INITIAL = 15
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_INITIAL, callbacks=[checkpoint_cb, earlystop_cb, reduce_lr])

# ==========================================================
# 🔓 Fine-tuning Phase
# ==========================================================
base_model.trainable = True
for layer in base_model.layers[:100]:  # Freeze early convolutional layers
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

EPOCHS_FINE = 25
history_fine = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_FINE, callbacks=[checkpoint_cb, earlystop_cb, reduce_lr])

# ==========================================================
# 🧾 Evaluation
# ==========================================================
model.load_weights('/content/resnet50_best_phase1.h5')
test_loss, test_acc = model.evaluate(test_gen, verbose=1)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

# Confusion Matrix
y_true = test_gen.classes
y_pred = np.argmax(model.predict(test_gen, verbose=0), axis=1)
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix — ResNet50 Baseline")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# ==========================================================
# 🧭 Training vs Validation Curves
# ==========================================================
acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history.history['loss'] + history_fine.history['loss']
val_loss = history.history['val_loss'] + history_fine.history['val_loss']

plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.plot(acc, label='Train Accuracy')
plt.plot(val_acc, label='Val Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")

plt.subplot(1,2,2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.show()

# ==========================================================
# 💾 Save Final Model
# ==========================================================
model.save('/content/colorectal_resnet50_finetuned_final.h5')
print("✅ Final Model Saved at /content/colorectal_resnet50_finetuned_final.h5")
# Out:
# Mounted at /content/drive
# ✅ Libraries ready
# 📦 Unzipping dataset from:
# → /content/drive/MyDrive/archive (2).zip
# ✅ Dataset root detected at: /content/Extracted_Kather/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000
#
# 📚 Classes detected:
#   - 01_TUMOR: 625 images
#   - 02_STROMA: 625 images
#   - 03_COMPLEX: 625 images
#   - 04_LYMPHO: 625 images
#   - 05_DEBRIS: 625 images
#   - 06_MUCOSA: 625 images
#   - 07_ADIPOSE: 625 images
#   - 08_EMPTY: 625 images
#
# ✅ Stratified Split Completed:
# {'train': 3256, 'val': 1000, 'test': 744}
# Found 3256 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# Found 744 images belonging to 8 classes.
#
# ✅ Detected 8 classes: ['01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO', '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,780,424 (94.53 MB)
#  Trainable params: 1,187,592 (4.53 MB)
#  Non-trainable params: 23,592,832 (90.00 MB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.3652 - loss: 1.9412
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 83s 657ms/step - accuracy: 0.3664 - loss: 1.9374 - val_accuracy: 0.7410 - val_loss: 0.8784 - learning_rate: 1.0000e-04
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.6583 - loss: 1.0545
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 519ms/step - accuracy: 0.6586 - loss: 1.0538 - val_accuracy: 0.8370 - val_loss: 0.6068 - learning_rate: 1.0000e-04
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.7200 - loss: 0.8689
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.7202 - loss: 0.8684 - val_accuracy: 0.8560 - val_loss: 0.5039 - learning_rate: 1.0000e-04
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.7761 - loss: 0.7257
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 512ms/step - accuracy: 0.7761 - loss: 0.7259 - val_accuracy: 0.8730 - val_loss: 0.4430 - learning_rate: 1.0000e-04
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.7987 - loss: 0.6766
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 51s 500ms/step - accuracy: 0.7987 - loss: 0.6767 - val_accuracy: 0.8900 - val_loss: 0.4150 - learning_rate: 1.0000e-04
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.8196 - loss: 0.6268
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 506ms/step - accuracy: 0.8195 - loss: 0.6268 - val_accuracy: 0.8880 - val_loss: 0.3952 - learning_rate: 1.0000e-04
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8034 - loss: 0.6308
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 512ms/step - accuracy: 0.8035 - loss: 0.6309 - val_accuracy: 0.8950 - val_loss: 0.3780 - learning_rate: 1.0000e-04
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.8236 - loss: 0.5942
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 83s 520ms/step - accuracy: 0.8236 - loss: 0.5940 - val_accuracy: 0.8990 - val_loss: 0.3724 - learning_rate: 1.0000e-04
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8190 - loss: 0.5919
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 506ms/step - accuracy: 0.8191 - loss: 0.5919 - val_accuracy: 0.8980 - val_loss: 0.3661 - learning_rate: 1.0000e-04
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8414 - loss: 0.5111
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 504ms/step - accuracy: 0.8414 - loss: 0.5112 - val_accuracy: 0.9000 - val_loss: 0.3544 - learning_rate: 1.0000e-04
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.8509 - loss: 0.5145
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 506ms/step - accuracy: 0.8508 - loss: 0.5147 - val_accuracy: 0.9040 - val_loss: 0.3486 - learning_rate: 1.0000e-04
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.8512 - loss: 0.5066
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 516ms/step - accuracy: 0.8512 - loss: 0.5066 - val_accuracy: 0.9060 - val_loss: 0.3385 - learning_rate: 1.0000e-04
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8579 - loss: 0.5030
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 513ms/step - accuracy: 0.8579 - loss: 0.5030 - val_accuracy: 0.9110 - val_loss: 0.3309 - learning_rate: 1.0000e-04
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8569 - loss: 0.5148
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 512ms/step - accuracy: 0.8569 - loss: 0.5147 - val_accuracy: 0.9180 - val_loss: 0.3228 - learning_rate: 1.0000e-04
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 507ms/step - accuracy: 0.8723 - loss: 0.4375 - val_accuracy: 0.9200 - val_loss: 0.3282 - learning_rate: 1.0000e-04
# Epoch 1/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 105s 711ms/step - accuracy: 0.7986 - loss: 0.6739 - val_accuracy: 0.9000 - val_loss: 0.3539 - learning_rate: 1.0000e-05
# Epoch 2/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 529ms/step - accuracy: 0.8283 - loss: 0.5430 - val_accuracy: 0.9130 - val_loss: 0.3457 - learning_rate: 1.0000e-05
# Epoch 3/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 538ms/step - accuracy: 0.8692 - loss: 0.4685 - val_accuracy: 0.9210 - val_loss: 0.3294 - learning_rate: 1.0000e-05
# Epoch 4/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8522 - loss: 0.4869
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 537ms/step - accuracy: 0.8523 - loss: 0.4869 - val_accuracy: 0.9300 - val_loss: 0.3146 - learning_rate: 1.0000e-05
# Epoch 5/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.8558 - loss: 0.5004
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 538ms/step - accuracy: 0.8559 - loss: 0.5003 - val_accuracy: 0.9360 - val_loss: 0.3005 - learning_rate: 1.0000e-05
# Epoch 6/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8700 - loss: 0.4521
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 537ms/step - accuracy: 0.8700 - loss: 0.4521 - val_accuracy: 0.9370 - val_loss: 0.2897 - learning_rate: 1.0000e-05
# Epoch 7/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8881 - loss: 0.3991
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.8881 - loss: 0.3994 - val_accuracy: 0.9360 - val_loss: 0.2822 - learning_rate: 1.0000e-05
# Epoch 8/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 526ms/step - accuracy: 0.8858 - loss: 0.4268 - val_accuracy: 0.9340 - val_loss: 0.2825 - learning_rate: 1.0000e-05
# Epoch 9/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.8842 - loss: 0.4105
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 57s 561ms/step - accuracy: 0.8843 - loss: 0.4105 - val_accuracy: 0.9360 - val_loss: 0.2727 - learning_rate: 1.0000e-05
# Epoch 10/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.8823 - loss: 0.4339
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 535ms/step - accuracy: 0.8824 - loss: 0.4336 - val_accuracy: 0.9410 - val_loss: 0.2685 - learning_rate: 1.0000e-05
# Epoch 11/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8923 - loss: 0.3866
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.8922 - loss: 0.3868 - val_accuracy: 0.9390 - val_loss: 0.2683 - learning_rate: 1.0000e-05
# Epoch 12/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8929 - loss: 0.4096
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 540ms/step - accuracy: 0.8929 - loss: 0.4096 - val_accuracy: 0.9410 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 13/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8991 - loss: 0.3571
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.8991 - loss: 0.3573 - val_accuracy: 0.9400 - val_loss: 0.2589 - learning_rate: 1.0000e-05
# Epoch 14/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.8826 - loss: 0.3966
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 538ms/step - accuracy: 0.8827 - loss: 0.3965 - val_accuracy: 0.9440 - val_loss: 0.2561 - learning_rate: 1.0000e-05
# Epoch 15/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.9037 - loss: 0.3634
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 548ms/step - accuracy: 0.9036 - loss: 0.3635 - val_accuracy: 0.9430 - val_loss: 0.2485 - learning_rate: 1.0000e-05
# Epoch 16/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.9094 - loss: 0.3542
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 57s 557ms/step - accuracy: 0.9094 - loss: 0.3543 - val_accuracy: 0.9440 - val_loss: 0.2479 - learning_rate: 1.0000e-05
# Epoch 17/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.9111 - loss: 0.3271
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 535ms/step - accuracy: 0.9110 - loss: 0.3272 - val_accuracy: 0.9470 - val_loss: 0.2472 - learning_rate: 1.0000e-05
# Epoch 18/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9054 - loss: 0.3407
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 542ms/step - accuracy: 0.9055 - loss: 0.3406 - val_accuracy: 0.9510 - val_loss: 0.2423 - learning_rate: 1.0000e-05
# Epoch 19/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.9157 - loss: 0.3329
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.9157 - loss: 0.3329 - val_accuracy: 0.9480 - val_loss: 0.2377 - learning_rate: 1.0000e-05
# Epoch 20/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9094 - loss: 0.3277
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 540ms/step - accuracy: 0.9094 - loss: 0.3278 - val_accuracy: 0.9470 - val_loss: 0.2367 - learning_rate: 1.0000e-05
# Epoch 21/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.9083 - loss: 0.3255
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 537ms/step - accuracy: 0.9084 - loss: 0.3256 - val_accuracy: 0.9510 - val_loss: 0.2347 - learning_rate: 1.0000e-05
# Epoch 22/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9178 - loss: 0.3186
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.9177 - loss: 0.3187 - val_accuracy: 0.9500 - val_loss: 0.2322 - learning_rate: 1.0000e-05
# Epoch 23/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.9268 - loss: 0.3120
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 81s 539ms/step - accuracy: 0.9267 - loss: 0.3120 - val_accuracy: 0.9510 - val_loss: 0.2254 - learning_rate: 1.0000e-05
# Epoch 24/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 531ms/step - accuracy: 0.9249 - loss: 0.3009 - val_accuracy: 0.9500 - val_loss: 0.2307 - learning_rate: 1.0000e-05
# Epoch 25/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 527ms/step - accuracy: 0.9137 - loss: 0.3227 - val_accuracy: 0.9500 - val_loss: 0.2285 - learning_rate: 1.0000e-05
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9561 - loss: 0.2367
#
# ✅ Test Accuracy: 96.24%
# ✅ Test Loss: 0.2054
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     01_TUMOR       0.98      0.98      0.98        93
#    02_STROMA       0.95      0.90      0.93        93
#   03_COMPLEX       0.89      0.95      0.92        93
#    04_LYMPHO       0.97      0.95      0.96        93
#    05_DEBRIS       0.92      0.96      0.94        93
#    06_MUCOSA       1.00      0.97      0.98        93
#   07_ADIPOSE       1.00      1.00      1.00        93
#     08_EMPTY       1.00      1.00      1.00        93
#
#     accuracy                           0.96       744
#    macro avg       0.96      0.96      0.96       744
# weighted avg       0.96      0.96      0.96       744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Final Model Saved at /content/colorectal_resnet50_finetuned_final.h5
